# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print(len(long_phrase) > len(short_phrase))
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
file_bytes = int(input('Введите объем файла в байтах для конвертирования в байтах: '))
# на всякий, проверка на отрицательное число
if file_bytes < 0:
    print('В этой части Вселенной объем файла не может быть отрицательным.')
else:
    print('Округленный объем файла равен: ', round(file_bytes/2**20,2),'Mb.')
# Out:
# Введите объем файла в байтах для конвертирования в байтах: 564654
# Округленный объем файла равен:  0.54 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
# не самое изящное решение, но мы еще на знаем обработчики ошибок, циклы, массивы и т.п.
# можно было бы отрезать месяц и день от введенной даты, но сказано в формате 'март', значит 'март' :)
# опять же можно было запихать все месяца в составные условия, но мне такое решение больше нравится

# интернет как бы говорит нам, что:
# Водолей	20.01 - 18.02
# Рыбы	19.02 - 20.03
# Овен	21.03 - 20.04
# Телец	21.04 - 20.05
# Близнецы	21.05 - 20.06
# Рак	21.06 - 22.07
# Лев	23.07 - 22.08
# Дева	23.08 - 23.09
# Весы	24.09 - 23.10
# Скорпион	24.10 - 21.11
# Стрелец	22.11 - 21.12
# Козерог	22.12 - 19.01

# для упрощения будем преобразовывать месяц и дату в число и сранивать по диапазонам
b_month = str(input('Введите месяц рождения (январь/февраль...): '))
b_day = int(input('Введите день рождения: '))
my_date = 0

if b_month == 'январь':
    my_date = 1
elif b_month == 'февраль':
    my_date = 2
elif b_month == 'март':
    my_date = 3
elif b_month == 'апрель':
    my_date = 4
elif b_month == 'май':
    my_date = 5
elif b_month == 'июнь':
    my_date = 6
elif b_month == 'июль':
    my_date = 7
elif b_month == 'август':
    my_date = 8
elif b_month == 'сентябрь':
    my_date = 9
elif b_month == 'октябрь':
    my_date = 10
elif b_month == 'ноябрь':
    my_date = 11
elif b_month == 'декабрь':
    my_date = 12

#   упрощенная проверка (без учета реальных дат, например, 31.02), но совсем без проверок как-то не комильфо
#   можно добавить в условия более строгие проверки на дни месяца, но тогда и високосный год надо учитывать
#   для теста, уверен, этого хватит

if my_date == 0 or not (1 <= b_day <= 31):
    print('Введены некорректный месяц или день. Пичаль.')
else:
    my_date = my_date*100 + b_day
    my_zodiac = 'Неведомая зверушка'

    if 120 <= my_date <= 218:
        my_zodiac = 'Водолей'
    elif 219 <= my_date <= 320:
        my_zodiac = 'Рыбы'
    elif 321 <= my_date <= 420:
        my_zodiac = 'Овен'
    elif 421 <= my_date <= 520:
        my_zodiac = 'Телец'
    elif 521 <= my_date <= 620:
        my_zodiac = 'Близнецы'
    elif 621 <= my_date <= 723:
        my_zodiac = 'Рак'
    elif 723 <= my_date <= 822:
        my_zodiac = 'Лев'
    elif 823 <= my_date <= 923:
        my_zodiac = 'Дева'
    elif 924 <= my_date <= 1023:
        my_zodiac = 'Весы'
    elif 1024 <= my_date <= 1121:
        my_zodiac = 'Скорпион'
    elif 1122 <= my_date <= 1221:
        my_zodiac = 'Стрелец'
    elif 1221 <= my_date <= 1231 or 101 <= my_date <= 119:
        my_zodiac = 'Козерог'

    print('Ваш знак зодика: ', my_zodiac)
    if my_zodiac == 'Неведомая зверушка':
        print('... и что-то пошло не так. Проверьте даты')
# Out:
# Введите месяц рождения (январь/февраль...): январь
# Введите день рождения: 31
# Ваш знак зодика:  Водолей

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
v_zp = int(input('Введите заработанную плату в месяц: '))
v_prcnt_ip = int(input('Введите сколько процентов уходит на ипотеку: '))
v_prcnt_lf = int(input('Введите сколько процентов уходит на жизнь: '))
v_bonus = int(input('Введите количество премий за год: '))

# очень базовые проверки, на всякий
# лучше их делать сразу при вводе, но мы, теоретически, еще не знаем нагугленный sys.exit()

if v_zp < 0:
    print('Жить в долг очень плохо. Введите положительную зп.')
elif not(0 < v_prcnt_ip <= 100) :
    print('Проверьте % ипотеки (он должен быть выше 0 и меньше 100%)')
elif not(0 < v_prcnt_lf <= 100) or (v_prcnt_ip + v_prcnt_lf > 100) :
    print('Проверьте % на жизнь (от 0 до 100%), либо сумму процентов на жизнь и иптотеку (д.б. меньше 100%)') 
elif not(0 <= v_bonus <= 12):
    print('Деньги портят людей. И премий в год может быть только от 0 до 12. Проверьте цифры.') 
# все ок, значит    
else:
    #всего v_zp*(12+v_bonus)
    #ипотека v_zp*v_prcnt_lf
    #отпуск 
    print('На ипотеку было потрачено: ', v_zp * 12 * v_prcnt_ip // 100, ' рублей')
    print('Было накоплено: ', v_zp * 12 * (100 - v_prcnt_ip - v_prcnt_lf) // 100 + v_zp * v_bonus // 2, ' рублей')
# Out:
# Введите заработанную плату в месяц: 1000
# Введите сколько процентов уходит на ипотеку: 50
# Введите сколько процентов уходит на жизнь: 60
# Введите количество премий за год: 0
# Проверьте % на жизнь (от 0 до 100%), либо сумму процентов на жизнь и иптотеку (д.б. меньше 100%)
