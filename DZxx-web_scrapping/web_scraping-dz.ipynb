# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
# для простоты исходим из того, что искомые слова могут быть в заголовке, тексте, хабах...
KEYWORDS = ['python', 'парсинг']
all_news = pd.DataFrame()

# на хабре, из того, что увидел, 50 страниц на все новости (можно сделать бесконечный цикл, но мне они не нравятся)
for page in range(50):
    time.sleep(0.2)
    soup = BeautifulSoup(requests.get(f'https://habr.com/ru/all/page{page+1}/').text, 'html.parser')
    for post in soup.find_all('article', class_='post post_preview'):
        if any([kwd in str(post).lower() for kwd in KEYWORDS]):
            all_news = (
                pd.concat([all_news,
                pd.DataFrame([
                {'page':str(page+1),
                'date': post.find('span', class_='post__time').text,
                'title': post.find('a', class_='post__title_link').text,
                'url': post.find('a', class_='post__title_link').attrs.get('href')}])],
                ignore_index=True)
                    )
all_news
# Out:
#    page                    date  \
# 0     1           вчера в 20:22
# 1     2           вчера в 16:16
# 2     2           вчера в 16:14
# 3     2           вчера в 14:53
# 4     3           вчера в 13:44
# ..  ...                     ...
# 65   49  5 августа 2020 в 16:48
# 66   50  5 августа 2020 в 14:00
# 67   50  5 августа 2020 в 13:47
# 68   50  5 августа 2020 в 13:10
# 69   50  5 августа 2020 в 12:55
#
#                                                 title  \
# 0   Киоск Raspberry Pi для графического интерфейса...
# 1   Разбор особенностей официального Docker-образа...
# 2   Полноценная игра, сделанная мною в обычной win...
# 3       3D ML. Часть 3: датасеты и фреймворки в 3D ML
# 4                Анализ сетей с использованием графов
# ..                                                ...
# 65  8 продвинутых возможностей модуля logging в Py...
# 66            Нет времени объяснять, сделай автопилот
# 67       Дешифровка текста методом частотного анализа
# 68         Canary деплой с Jenkins-X, Istio и Flagger
# 69  Разбор статьи из журнала «Код» (Яндекс Практикум)
#
#                                                url
# 0                 https://habr.com/ru/post/516542/
# 1   https://habr.com/ru/company/ruvds/blog/516310/
# 2                 https://habr.com/ru/post/516548/
# 3   https://habr.com/ru/company/itmai/blog/516404/
# 4                 https://habr.com/ru/post/516514/
# ..                                             ...
# 65                https://habr.com/ru/post/513966/
# 66    https://habr.com/ru/company/ods/blog/513604/
# 67                https://habr.com/ru/post/513926/
# 68  https://habr.com/ru/company/nixys/blog/513918/
# 69                https://habr.com/ru/post/513910/
#
# [70 rows x 4 columns]

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст статьи>

# %%
# окай. надо просто добавить переход по ссылкам
KEYWORDS = ['python', 'парсинг']
all_news = pd.DataFrame()

# ограничимся 2мя страницами для примера, но можно собрать и со всех
# можно через функцию, но проще 2 строчки добавить к имеющемуся скрипту
for page in range(2):
    soup = BeautifulSoup(requests.get(f'https://habr.com/ru/all/page{page+1}/').text, 'html.parser')
    for post in soup.find_all('article', class_='post post_preview'):
        time.sleep(0.2)        
        soup_full = BeautifulSoup(requests.get(post.find('a', class_='post__title_link').attrs.get('href')).text, 'html.parser')
        post_full = soup_full.find('article', class_='post post_full')
        if any([kwd in str(post_full).lower() for kwd in KEYWORDS]):
            all_news = (
                pd.concat([all_news,
                pd.DataFrame([
                {'page':str(page+1),
                'date': post.find('span', class_='post__time').text,
                'title': post.find('a', class_='post__title_link').text,
                'url': post.find('a', class_='post__title_link').attrs.get('href'),
                'body': post_full.find('div', class_='post__text').text,}])],
                ignore_index=True)
                    )
all_news
# Out:
#   page           date                                              title  \
# 0    1  вчера в 20:22  Киоск Raspberry Pi для графического интерфейса...
# 1    1  вчера в 18:44      7 интересных хаков с Black Hat / DEF CON 2020
# 2    1  вчера в 17:41  Обратный перевод для Нейронного машинного пере...
# 3    2  вчера в 16:16  Разбор особенностей официального Docker-образа...
# 4    2  вчера в 16:14  Полноценная игра, сделанная мною в обычной win...
# 5    2  вчера в 15:10  Azure IoT Edge и SQL Edge: перенос облачных на...
# 6    2  вчера в 14:53      3D ML. Часть 3: датасеты и фреймворки в 3D ML
# 7    2  вчера в 14:45              Телепортация тонн данных в PostgreSQL
#
#                                                 url  \
# 0                  https://habr.com/ru/post/516542/
# 1  https://habr.com/ru/company/it-grad/blog/516570/
# 2                  https://habr.com/ru/post/491794/
# 3    https://habr.com/ru/company/ruvds/blog/516310/
# 4                  https://habr.com/ru/post/516548/
# 5   https://habr.com/ru/company/quarta/blog/516432/
# 6    https://habr.com/ru/company/itmai/blog/516404/
# 7   https://habr.com/ru/company/tensor/blog/516384/
#
#                                                 body
# 0  Привет, Хабр!\n\r\nХочется поделиться опытом н...
# 1  Под катом приглядимся повнимательнее к некотор...
# 2  Привет. Некоторое время назад я рассказывал пр...
# 3  Официальный Docker-образ Python весьма популяр...
# 4  Привет! \r\nСегодня я опишу в подробностях, ка...
# 5  Azure IoT Edge — это дополнение к IoT Hub, кот...
# 6  \nРаботая в конкретной предметной области в ра...
# 7  Сегодня я поделюсь некоторыми полезными архите...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
EMAIL = ['test@ya.ru', 'test@mail.ru']
df_res = pd.DataFrame()

URL = 'https://digibody.avast.com/v1/web/leaks'

for eml in EMAIL:
    time.sleep(0.2)
    data = {'email': eml}
    req = requests.post(URL, json=data)    
    
    df = pd.DataFrame(req.json()['value'])
    df['date of leak'], df['title'], df['description'] = (
        zip(*df.apply(lambda x:
        (datetime.fromtimestamp(x.leak_date/1000).strftime('%Y-%m-%d'),
        x['leak_info']['title'],
        x['leak_info']['description']), axis=1))
    )
    # в результатах высвечиваются какие-то левые e-mail. на всякий, я их убрал. можно это не делать
    df = df[df.username==eml][['username', 'date of leak', 'domain', 'title', 'description']]
    df_res = pd.concat([df_res, df], ignore_index=True)

df_res.columns = ['почта', 'дата утечки', 'источник утечки', 'описание утечки', 'описание утечки полное']
df_res
# Out:
#            почта дата утечки         источник утечки  \
# 0     test@ya.ru  2018-08-24
# 1     test@ya.ru  2019-02-06
# 2     test@ya.ru  2017-01-16              aristos.pw
# 3     test@ya.ru  2020-05-21          bitrewards.com
# 4     test@ya.ru  2016-10-24             dropbox.com
# 5     test@ya.ru  2018-12-13
# 6     test@ya.ru  2019-02-06
# 7     test@ya.ru  2017-04-04               evony.com
# 8     test@ya.ru  2020-01-09
# 9     test@ya.ru  2019-02-06
# 10    test@ya.ru  2019-10-31             gatehub.net
# 11    test@ya.ru  2016-12-15              aristos.pw
# 12    test@ya.ru  2019-01-29
# 13    test@ya.ru  2018-06-12
# 14    test@ya.ru  2018-02-18              disqus.com
# 15    test@ya.ru  2018-11-29
# 16    test@ya.ru  2019-02-06
# 17    test@ya.ru  2019-01-25
# 18    test@ya.ru  2016-11-01                  qip.ru
# 19    test@ya.ru  2019-12-05
# 20    test@ya.ru  2016-10-25              tumblr.com
# 21    test@ya.ru  2020-08-13
# 22  test@mail.ru  2019-07-25           cafepress.com
# 23  test@mail.ru  2019-02-06
# 24  test@mail.ru  2020-05-21          bitrewards.com
# 25  test@mail.ru  2020-08-13           verified.cash
# 26  test@mail.ru  2020-03-12
# 27  test@mail.ru  2020-02-20
# 28  test@mail.ru  2020-04-30  thetoywholesaler.co.uk
# 29  test@mail.ru  2019-02-06
# 30  test@mail.ru  2019-03-14          streeteasy.com
# 31  test@mail.ru  2019-03-07           sharethis.com
# 32  test@mail.ru  2020-08-13
# 33  test@mail.ru  2019-10-10
# 34  test@mail.ru  2020-01-09
# 35  test@mail.ru  2019-02-06
# 36  test@mail.ru  2020-01-30         lekoolgames.com
# 37  test@mail.ru  2020-06-25
# 38  test@mail.ru  2020-04-23             aptoide.com
# 39  test@mail.ru  2020-04-09               vkmix.com
# 40  test@mail.ru  2020-05-28
# 41  test@mail.ru  2019-02-28                8fit.com
# 42  test@mail.ru  2020-07-16       synergyregions.ru
# 43  test@mail.ru  2020-04-02
# 44  test@mail.ru  2020-07-09
# 45  test@mail.ru  2019-11-07
# 46  test@mail.ru  2019-02-06
# 47  test@mail.ru  2019-03-14               artsy.net
# 48  test@mail.ru  2020-06-25
# 49  test@mail.ru  2020-02-13
# 50  test@mail.ru  2019-03-20              roll20.net
# 51  test@mail.ru  2019-12-05
# 52  test@mail.ru  2019-10-03             lencrier.ca
# 53  test@mail.ru  2020-08-13
#
#                     описание утечки  \
# 0     Jadid List from Pemiblanc.com
# 1          Collection #4 Combo List
# 2                           Aristos
# 3                        BitRewards
# 4                           Dropbox
# 5                  Sensitive Source
# 6          Collection #5 Combo List
# 7                             Evony
# 8                  Sensitive Source
# 9        2019 Antipublic Combo List
# 10                          Gatehub
# 11                          Aristos
# 12         Collection #2 Combo List
# 13                 Sensitive Source
# 14                           Disqus
# 15                 Sensitive Source
# 16    AP MYR and Zabugor Combo List
# 17         Collection #1 Combo List
# 18                              Qip
# 19                 Sensitive Source
# 20                           Tumblr
# 21  "AntiPub Drugs Squad" Combolist
# 22                        CafePress
# 23         Collection #4 Combo List
# 24                       BitRewards
# 25                    Verified.Cash
# 26                   AzorUlt Botnet
# 27                   AzorUlt Botnet
# 28                   Netpricedirect
# 29         Collection #5 Combo List
# 30                       Streeteasy
# 31                        ShareThis
# 32                    Vidar Stealer
# 33                   AzorUlt Botnet
# 34                 Sensitive Source
# 35       2019 Antipublic Combo List
# 36                     Lekool Games
# 37           Freedom Fox Combo List
# 38                          Aptoide
# 39                           VK Mix
# 40                 Sensitive Source
# 41                             8fit
# 42            Университет синергия
# 43         Russian Password Stealer
# 44                    Vidar Stealer
# 45                    Masad Stealer
# 46    AP MYR and Zabugor Combo List
# 47                            Artsy
# 48   "Cash Cloud" Retail Combo List
# 49                   AzorUlt Botnet
# 50                           Roll20
# 51                 Sensitive Source
# 52                         Lencrier
# 53  "AntiPub Drugs Squad" Combolist
#
#                                описание утечки полное
# 0   This combolist was compiled from a variety of ...
# 1   On January 7, 2019, an online user named Sanix...
# 2   In September 2016, Aristos.pw was breached. Th...
# 3   In April 2020, the e-commerce platform BitRewa...
# 4   Cloud storage company Dropbox suffered a major...
# 5   This source has been marked as sensitive due t...
# 6   On January 7, 2019, an online user named Sanix...
# 7   In July 2016, gaming site Evony's user databas...
# 8   This source has been marked as sensitive due t...
# 9   On January 7, 2019, an online user named Sanix...
# 10  At an unconfirmed date, the online crypto curr...
# 11  In September 2016, Russian online retail compa...
# 12  On January 7, 2019, an online user named Sanix...
# 13  This source has been marked as sensitive due t...
# 14  In 2012, comment hosting service Disqus's data...
# 15  This source has been marked as sensitive due t...
# 16  On January 7, 2019, an online user named Sanix...
# 17  On January 7, 2019, an online user named Sanix...
# 18  In 2011, Russian instant messaging service pro...
# 19  This source has been marked as sensitive due t...
# 20  In May 2016, microblogging platform Tumblr rev...
# 21  In August 2020, this combolist was shared on a...
# 22  In February 2019, custom merchandise retailer ...
# 23  On January 7, 2019, an online user named Sanix...
# 24  In April 2020, the e-commerce platform BitRewa...
# 25  At an unconfirmed date, the now-defunct hackin...
# 26  AzorUlt is a lesser known credential stealing ...
# 27  AzorUlt is a lesser known credential stealing ...
# 28  At an unconfirmed date, the UK online toy reta...
# 29  On January 7, 2019, an online user named Sanix...
# 30  In June 2018, Streeteasy's database was allege...
# 31  In July 2018, ShareThis's database was alleged...
# 32  Vidar Stealer is a Windows-targeted stealer de...
# 33  AzorUlt is a lesser known credential stealing ...
# 34  This source has been marked as sensitive due t...
# 35  On January 7, 2019, an online user named Sanix...
# 36  At an unconfirmed date, the online gaming site...
# 37  At an unconfirmed date, an unspecified combo l...
# 38  In April 2020, the software marketplace app Ap...
# 39  At an unconfirmed date, the Russian social med...
# 40  This source has been marked as sensitive due t...
# 41  In July 2018, 8fit's database was allegedly br...
# 42  At an unconfirmed date, the Russian university...
# 43  This unnamed stealer is of Russian origin and ...
# 44  Vidar Stealer is a Windows-targeted stealer de...
# 45  Massad Stealer is a type of spyware that uses ...
# 46  On January 7, 2019, an online user named Sanix...
# 47  In May 2018, Artsy's database was allegedly br...
# 48  At an unconfirmed date, this "Cash Cloud" Reta...
# 49  AzorUlt is a lesser known credential stealing ...
# 50  In January 2019, Roll20 allegedly breached. Th...
# 51  This source has been marked as sensitive due t...
# 52  At an unknown date, printer supply store Lencr...
# 53  In August 2020, this combolist was shared on a...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>.

# %%
# решил таки заморочиться с получением токена
NEWSFEED_REQUEST = 'https://api.vk.com/method/wall.get?'
TOKEN = 'был тут'
VERSION = '5.122'
SLEEP = 0.33

# %%
params = {
    'access_token': TOKEN,
    'domain': 'netology',
    'v': VERSION,
    'count': 50
}
res = requests.get(NEWSFEED_REQUEST, params)
df = pd.DataFrame(res.json()['response']['items'])
df['dt'] = df.apply(lambda x: datetime.fromtimestamp(x.date).strftime('%Y-%m-%d'), axis=1)
df = df[['dt', 'text']]
df.columns = ['дата поста', 'текст поста']
df
# Out:
#     дата поста                                        текст поста
# 0   2020-08-22  А ю рэди? 🕺 На следующей неделе учимся выступа...
# 1   2020-08-26  Казалось бы, общение — это просто. Кто-то гово...
